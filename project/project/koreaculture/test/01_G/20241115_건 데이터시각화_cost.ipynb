# %%
import pandas as pd

# 엑셀 파일을 읽어옵니다
code_df = pd.read_excel("../../data/국민여가활동조사_2023_항목정의서.xlsx")  # 파일 경로를 지정하세요

# 데이터프레임을 리스트로 변환합니다
data_list = code_df.values.tolist()

code_dict = {}

for key, value in data_list:
    code_dict[key] = value

code_dict
# Out:
# {'ID': '응답자 ID',
#  'EUP': '시부군부 유형',
#  'AREA': '시도권역',
#  'APT': '주택유형',
#  'Q1_1': '한 번 이상 참여한 여가활동 - (1) 전시회 관람(미술, 사진, 건축, 디자인 등)',
#  'Q1_2': '한 번 이상 참여한 여가활동 - (2) 박물관 관람',
#  'Q1_3': '한 번 이상 참여한 여가활동 - (3) 음악연주회 관람(클래식, 오페라 등)',
#  'Q1_4': '한 번 이상 참여한 여가활동 - (4) 전통예술공연 관람(국악, 민속놀이 등)',
#  'Q1_5': '한 번 이상 참여한 여가활동 - (5) 연극공연 관람(뮤지컬 포함)',
#  'Q1_6': '한 번 이상 참여한 여가활동 - (6) 무용공연 관람',
#  'Q1_7': '한 번 이상 참여한 여가활동 - (7) 영화관람',
#  'Q1_8': '한 번 이상 참여한 여가활동 - (8) 연예공연 관람(쇼, 콘서트, 마술 쇼 등)',
#  'Q1_9': '한 번 이상 참여한 여가활동 - (9) 문학행사참여',
#  'Q1_10': '한 번 이상 참여한 여가활동 - (10) 글짓기/독서토론',
#  'Q1_11': '한 번 이상 참여한 여가활동 - (11) 미술활동(그림, 서예, 조각, 디자인, 도예, 만화 등)',
#  'Q1_12': '한 번 이상 참여한 여가활동 - (12) 악기연주/노래교실',
#  'Q1_13': '한 번 이상 참여한 여가활동 - (13) 전통예술 배우기(사물놀이, 줄타기 등)',
#  'Q1_14': '한 번 이상 참여한 여가활동 - (14) 사진촬영(디지털카메라 포함)',
#  'Q1_15': '한 번 이상 참여한 여가활동 - (15) 춤/무용(발레, 한국무용, 현대무용, 방송댄스, 스트릿댄스, 비보잉 등)',
#  'Q1_16': '한 번 이상 참여한 여가활동 - (16) 스포츠 경기 직접관람- 경기장방문관람(축구, 야구,농구, 배구 등)',
#  'Q1_17': '한 번 이상 참여한 여가활동 - (17) 스포츠 경기 간접관람- TV, DMB를 통한관람(축구, 야구, 농구, 배구 등)',
#  'Q1_18': '한 번 이상 참여한 여가활동 - (18) 격투 스포츠 경기관람(태권도, 유도, 합기도, 검도,권투 등)',
#  'Q1_19': '한 번 이상 참여한 여가활동 - (19) 온라인게임 경기관람(e-스포츠 경기 포함)',
#  'Q1_20': '한 번 이상 참여한 여가활동 - (20) 농구, 배구, 야구, 축구, 족구',
#  'Q1_21': '한 번 이상 참여한 여가활동 - (21) 테니스, 스쿼시',
#  'Q1_22': '한 번 이상 참여한 여가활동 - (22) 당구/포켓볼',
#  'Q1_23': '한 번 이상 참여한 여가활동 - (23) 볼링, 탁구',
#  'Q1_24': '한 번 이상 참여한 여가활동 - (24) 골프',
#  'Q1_25': '한 번 이상 참여한 여가활동 - (25) 수영',
#  'Q1_26': '한 번 이상 참여한 여가활동 - (26) 윈드서핑, 수상스키, 스킨스쿠버다이빙, 래프팅, 요트',
#  'Q1_27': '한 번 이상 참여한 여가활동 - (27) 스노보드, 스키 등',
#  'Q1_28': '한 번 이상 참여한 여가활동 - (28) 아이스스케이트, 아이스하키 등',
#  'Q1_29': '한 번 이상 참여한 여가활동 - (29) 헬스(PT,보디빌딩)/에어로빅/크로스핏',
#  'Q1_30': '한 번 이상 참여한 여가활동 - (30) 요가/필라테스/태보',
#  'Q1_31': '한 번 이상 참여한 여가활동 - (31) 배드민턴/줄넘기/맨손, 스트레칭 체조/훌라후프',
#  'Q1_32': '한 번 이상 참여한 여가활동 - (32) 러닝/조깅/마라톤',
#  'Q1_33': '한 번 이상 참여한 여가활동 - (33) 격투 스포츠(태권도, 유도, 합기도, 검도, 권투 등)',
#  'Q1_34': '한 번 이상 참여한 여가활동 - (34) 댄스스포츠(탱고, 왈츠, 자이브, 맘보,폴카, 차차차등)',
#  'Q1_35': '한 번 이상 참여한 여가활동 - (35) 사이클링/산악자전거',
#  'Q1_36': '한 번 이상 참여한 여가활동 - (36) 인라인스케이트',
#  'Q1_37': '한 번 이상 참여한 여가활동 - (37) 승마, 암벽등반, 철인삼종경기, 서바이벌',
#  'Q1_38': '한 번 이상 참여한 여가활동 - (38) 문화유적방문(고궁, 절, 유적지 등)',
#  'Q1_39': '한 번 이상 참여한 여가활동 - (39) 자연명승 및 풍경 관람',
#  'Q1_40': '한 번 이상 참여한 여가활동 - (40) 삼림욕',
#  'Q1_41': '한 번 이상 참여한 여가활동 - (41) 국내캠핑',
#  'Q1_42': '한 번 이상 참여한 여가활동 - (42) 해외여행',
#  'Q1_43': '한 번 이상 참여한 여가활동 - (43) 소풍/야유회',
#  'Q1_44': '한 번 이상 참여한 여가활동 - (44) 온천/해수욕',
#  'Q1_45': '한 번 이상 참여한 여가활동 - (45) 유람선 타기',
#  'Q1_46': '한 번 이상 참여한 여가활동 - (46) 테마파크가기/놀이공원/동물원/식물원 가기',
#  'Q1_47': '한 번 이상 참여한 여가활동 - (47) 지역축제 참가',
#  'Q1_48': '한 번 이상 참여한 여가활동 - (48) 자동차 드라이브',
#  'Q1_49': '한 번 이상 참여한 여가활동 - (49) 수집활동(스크랩 포함)',
#  'Q1_50': '한 번 이상 참여한 여가활동 - (50) 생활공예(십자수, 비즈공예, D.I.Y, 꽃꽂이 등)',
#  'Q1_51': '한 번 이상 참여한 여가활동 - (51) 요리하기/다도',
#  'Q1_52': '한 번 이상 참여한 여가활동 - (52) 반려동물 돌보기',
#  'Q1_53': '한 번 이상 참여한 여가활동 - (53) 노래방 가기',
#  'Q1_54': '한 번 이상 참여한 여가활동 - (54) 인테리어(집, 자동차 등)',
#  'Q1_55': '한 번 이상 참여한 여가활동 - (55) 등산',
#  'Q1_56': '한 번 이상 참여한 여가활동 - (56) 낚시',
#  'Q1_57': '한 번 이상 참여한 여가활동 - (57) 홈페이지/블로그 관리',
#  'Q1_58': '한 번 이상 참여한 여가활동 - (58) 인터넷 검색/1인 미디어 제작/SNS/영상편집',
#  'Q1_59': '한 번 이상 참여한 여가활동 - (59) 게임(온라인/모바일/콘솔게임 등)',
#  'Q1_60': '한 번 이상 참여한 여가활동 - (60) 보드게임/퍼즐/큐브 맞추기',
#  'Q1_61': '한 번 이상 참여한 여가활동 - (61) 바둑/장기/체스',
#  'Q1_62': '한 번 이상 참여한 여가활동 - (62) 겜블(경마, 경륜, 카지노, 카드놀이, 고스톱, 마작 등)/복권구입',
#  'Q1_63': '한 번 이상 참여한 여가활동 - (63) 쇼핑/외식',
#  'Q1_64': '한 번 이상 참여한 여가활동 - (64) 음주',
#  'Q1_65': '한 번 이상 참여한 여가활동 - (65) 독서(웹소설 포함)',
#  'Q1_66': '한 번 이상 참여한 여가활동 - (66) 만화보기(웹툰 포함)',
#  'Q1_67': '한 번 이상 참여한 여가활동 - (67) 미용(피부관리, 헤어관리, 네일아트, 마사지, 성형 등)',
#  'Q1_68': '한 번 이상 참여한 여가활동 - (68) 어학/기술/자격증 취득 공부/학원 등 이용',
#  'Q1_69': '한 번 이상 참여한 여가활동 - (69) 이색/테마카페 체험(방탈출, VR, 낚시카페 등)',
#  'Q1_70': '한 번 이상 참여한 여가활동 - (70) 원예(화분, 화단가꾸기 등)',
#  'Q1_71': '한 번 이상 참여한 여가활동 - (71) 산책 및 걷기',
#  'Q1_72': '한 번 이상 참여한 여가활동 - (72) 목욕/사우나/찜질방',
#  'Q1_73': '한 번 이상 참여한 여가활동 - (73) 낮잠',
#  'Q1_74': '한 번 이상 참여한 여가활동 - (74) TV시청(IPTV 포함)',
#  'Q1_75': '한 번 이상 참여한 여가활동 - (75) 모바일 컨텐츠, 동영상, VOD 시청, OTT 시청',
#  'Q1_76': '한 번 이상 참여한 여가활동 - (76) 라디오/팟캐스트 청취',
#  'Q1_77': '한 번 이상 참여한 여가활동 - (77) 음악 감상',
#  'Q1_78': '한 번 이상 참여한 여가활동 - (78) 신문/잡지보기',
#  'Q1_79': '한 번 이상 참여한 여가활동 - (79) 아무것도 안 하기',
#  'Q1_80': '한 번 이상 참여한 여가활동 - (80) 사회봉사활동',
#  'Q1_81': '한 번 이상 참여한 여가활동 - (81) 종교활동',
#  'Q1_82': '한 번 이상 참여한 여가활동 - (82) 클럽/나이트/디스코/캬바레 가기',
#  'Q1_83': '한 번 이상 참여한 여가활동 - (83) 가족 및 친지방문',
#  'Q1_84': '한 번 이상 참여한 여가활동 - (84) 잡담/통화하기/문자보내기(모바일 메신저 메시지 사용 포함)',
#  'Q1_85': '한 번 이상 참여한 여가활동 - (85) 계모임/동창회/사교(파티)모임',
#  'Q1_86': '한 번 이상 참여한 여가활동 - (86) 친구만남/이성교제/미팅/소개팅',
#  'Q1_87': '한 번 이상 참여한 여가활동 - (87) 동호회 모임',
#  'Q1_88': '한 번 이상 참여한 여가활동 - (88) 위에서 분류되지 않은 기타 여가활동',
#  'Q1_89': '한 번 이상 참여한 여가활동 - (89) 독서/만화책(웹툰)보기(2014,2016,2018)',
#  'Q1_90': '한 번 이상 참여한 여가활동 - (90) 이성교제(데이트)/미팅/소개팅(2014,2016,2018)',
#  'Q1_91': '한 번 이상 참여한 여가활동 - (91) 친구만남/동호회 모임(2014,2016,2018)',
#  'Q2_1_1': '지난 1년간 가장 많이 참여한 여가활동 (1순위)',
#  'Q2_1_2': '지난 1년간 가장 많이 참여한 여가활동 (2순위)',
#  'Q2_1_3': '지난 1년간 가장 많이 참여한 여가활동 (3순위)',
#  'Q2_1_4': '지난 1년간 가장 많이 참여한 여가활동 (4순위)',
#  'Q2_1_5': '지난 1년간 가장 많이 참여한 여가활동 (5순위)',
#  'Q2_2_1': '지난 1년간 가장 많이 참여한 여가활동 동반자(1순위)',
#  'Q2_2_2': '지난 1년간 가장 많이 참여한 여가활동 동반자(2순위)',
#  'Q2_2_3': '지난 1년간 가장 많이 참여한 여가활동 동반자(3순위)',
#  'Q2_2_4': '지난 1년간 가장 많이 참여한 여가활동 동반자(4순위)',
#  'Q2_2_5': '지난 1년간 가장 많이 참여한 여가활동 동반자(5순위)',
#  'Q2_2_1_T': '지난 1년간 가장 많이 참여한 여가활동 동반자 - 기타(1순위)',
#  'Q2_2_2_T': '지난 1년간 가장 많이 참여한 여가활동 동반자 - 기타(2순위)',
#  'Q2_2_3_T': '지난 1년간 가장 많이 참여한 여가활동 동반자 - 기타(3순위)',
#  'Q2_2_4_T': '지난 1년간 가장 많이 참여한 여가활동 동반자 - 기타(4순위)',
#  'Q2_2_5_T': '지난 1년간 가장 많이 참여한 여가활동 동반자 - 기타(5순위)',
#  'Q2_3_1': '지난 1년간 가장 많이 참여한 여가활동 빈도(1순위)',
#  'Q2_3_2': '지난 1년간 가장 많이 참여한 여가활동 빈도(2순위)',
#  'Q2_3_3': '지난 1년간 가장 많이 참여한 여가활동 빈도(3순위)',
#  'Q2_3_4': '지난 1년간 가장 많이 참여한 여가활동 빈도(4순위)',
#  'Q2_3_5': '지난 1년간 가장 많이 참여한 여가활동 빈도(5순위)',
#  'Q2_3_1_T': '지난 1년간 가장 많이 참여한 여가활동 빈도 - 기타(1순위)',
#  'Q2_3_2_T': '지난 1년간 가장 많이 참여한 여가활동 빈도 - 기타(2순위)',
#  'Q2_3_3_T': '지난 1년간 가장 많이 참여한 여가활동 빈도 - 기타(3순위)',
#  'Q2_3_4_T': '지난 1년간 가장 많이 참여한 여가활동 빈도 - 기타(4순위)',
#  'Q2_3_5_T': '지난 1년간 가장 많이 참여한 여가활동 빈도 - 기타(5순위)',
#  'Q2_4_1_1_N': '지난 1년간 가장 많이 참여한 여가활동 1회 여가 소요시간 - 시간(1순위)',
#  'Q2_4_1_2_N': '지난 1년간 가장 많이 참여한 여가활동 1회 여가 소요시간 - 분(1순위)',
#  'Q2_4_2_1_N': '지난 1년간 가장 많이 참여한 여가활동 1회 여가 소요시간 - 시간(2순위)',
#  'Q2_4_2_2_N': '지난 1년간 가장 많이 참여한 여가활동 1회 여가 소요시간 - 분(2순위)',
#  'Q2_4_3_1_N': '지난 1년간 가장 많이 참여한 여가활동 1회 여가 소요시간 - 시간(3순위)',
#  'Q2_4_3_2_N': '지난 1년간 가장 많이 참여한 여가활동 1회 여가 소요시간 - 분(3순위)',
#  'Q2_4_4_1_N': '지난 1년간 가장 많이 참여한 여가활동 1회 여가 소요시간 - 시간(4순위)',
#  'Q2_4_4_2_N': '지난 1년간 가장 많이 참여한 여가활동 1회 여가 소요시간 - 분(4순위)',
#  'Q2_4_5_1_N': '지난 1년간 가장 많이 참여한 여가활동 1회 여가 소요시간 - 시간(5순위)',
#  'Q2_4_5_2_N': '지난 1년간 가장 많이 참여한 여가활동 1회 여가 소요시간 - 분(5순위)',
#  'Q2_5_1_N': '지난 1년간 가장 많이 참여한 여가활동 1회 기준 비용(1순위)',
#  'Q2_5_2_N': '지난 1년간 가장 많이 참여한 여가활동 1회 기준 비용(2순위)',
#  'Q2_5_3_N': '지난 1년간 가장 많이 참여한 여가활동 1회 기준 비용(3순위)',
#  'Q2_5_4_N': '지난 1년간 가장 많이 참여한 여가활동 1회 기준 비용(4순위)',
#  'Q2_5_5_N': '지난 1년간 가장 많이 참여한 여가활동 1회 기준 비용(5순위)',
#  'Q2_6_1': '지난 1년간 가장 많이 참여한 여가활동 만족도(1순위)',
#  'Q2_6_2': '지난 1년간 가장 많이 참여한 여가활동 만족도(2순위)',
#  'Q2_6_3': '지난 1년간 가장 많이 참여한 여가활동 만족도(3순위)',
#  'Q2_6_4': '지난 1년간 가장 많이 참여한 여가활동 만족도(4순위)',
#  'Q2_6_5': '지난 1년간 가장 많이 참여한 여가활동 만족도(5순위)',
#  'Q3': '여가활동 주 목적',
#  'Q3_T': '여가활동 주 목적 - 기타',
#  'Q4_1': '가장 만족스런 여가활동 (1순위)',
#  'Q4_2': '가장 만족스런 여가활동 (2순위)',
#  'Q4_3': '가장 만족스런 여가활동 (3순위)',
#  'Q5_1_A': '지난 1년간 가장 많이 참여한 유형별 여가활동 -A. 문화예술 관람 활동',
#  'Q5_2_A': '유형별 여가활동 만족도 -A. 문화예술 관람 활동',
#  'Q5_3_A': '평일에 희망하는 여가활동 -A. 문화예술 관람 활동',
#  'Q5_4_A': '휴일에 희망하는 여가활동 -A. 문화예술 관람 활동',
#  'Q5_1_B': '지난 1년간 가장 많이 참여한 유형별 여가활동 -B. 문화예술 참여 활동',
#  'Q5_2_B': '유형별 여가활동 만족도 -B. 문화예술 참여 활동',
#  'Q5_3_B': '평일에 희망하는 여가활동 -B. 문화예술 참여 활동',
#  'Q5_4_B': '휴일에 희망하는 여가활동 -B. 문화예술 참여 활동',
#  'Q5_1_C': '지난 1년간 가장 많이 참여한 유형별 여가활동 -C. 스포츠 관람 활동',
#  'Q5_2_C': '유형별 여가활동 만족도 -C. 스포츠 관람 활동',
#  'Q5_3_C': '평일에 희망하는 여가활동 -C. 스포츠 관람 활동',
#  'Q5_4_C': '휴일에 희망하는 여가활동 -C. 스포츠 관람 활동',
#  'Q5_1_D': '지난 1년간 가장 많이 참여한 유형별 여가활동 -D. 스포츠 참여 활동',
#  'Q5_2_D': '유형별 여가활동 만족도 -D. 스포츠 참여 활동',
#  'Q5_3_D': '평일에 희망하는 여가활동 -D. 스포츠 참여 활동',
#  'Q5_4_D': '휴일에 희망하는 여가활동 -D. 스포츠 참여 활동',
#  'Q5_1_E': '지난 1년간 가장 많이 참여한 유형별 여가활동 -E. 관광활동',
#  'Q5_2_E': '유형별 여가활동 만족도 -E. 관광활동',
#  'Q5_3_E': '평일에 희망하는 여가활동 -E. 관광활동',
#  'Q5_4_E': '휴일에 희망하는 여가활동 -E. 관광활동',
#  'Q5_1_F': '지난 1년간 가장 많이 참여한 유형별 여가활동 -F. 취미오락 활동',
#  'Q5_2_F': '유형별 여가활동 만족도 -F. 취미오락 활동',
#  'Q5_3_F': '평일에 희망하는 여가활동 -F. 취미오락 활동',
#  'Q5_4_F': '휴일에 희망하는 여가활동 -F. 취미오락 활동',
#  'Q5_1_G': '지난 1년간 가장 많이 참여한 유형별 여가활동 -G. 휴식활동',
#  'Q5_2_G': '유형별 여가활동 만족도 -G. 휴식활동',
#  'Q5_3_G': '평일에 희망하는 여가활동 -G. 휴식활동',
#  'Q5_4_G': '휴일에 희망하는 여가활동 -G. 휴식활동',
#  'Q5_1_H': '지난 1년간 가장 많이 참여한 유형별 여가활동 -H. 사회 및 기타 활동',
#  'Q5_2_H': '유형별 여가활동 만족도 -H. 사회 및 기타 활동',
#  'Q5_3_H': '평일에 희망하는 여가활동 -H. 사회 및 기타 활동',
#  'Q5_4_H': '휴일에 희망하는 여가활동 -H. 사회 및 기타 활동',
#  'Q6': '여가경력- 반복참여 경험',
#  'Q7': '지속적으로 참여하는 여가활동 중 가장 많이하는 활동',
#  'Q7_T': '지속적으로 참여하는 여가활동 중 가장 많이하는 활동 - 상세유형 (주관식)',
#  'Q8_1_N': '지속적/반복적으로 참여하는 여가활동 - 참여기간(년)',
#  'Q8_2_N': '지속적/반복적으로 참여하는 여가활동 - 참여기간(개월)',
#  'Q9_N': '지난 1년간 여가활동을 위한 지출액(월 평균)',
#  'Q9_1': '지난 1년간 지출한 여가비의 충분도',
#  'Q10_N': '적절하다고 생각하는 여가비용(월 평균)',
#  'Q11_1_1_N': '지난 1년 간 하루 평균 여가시간 - 평일',
#  'Q11_2_1': '지난 1년 간 여가시간 충분도 - 평일',
#  'Q11_3_1': '지난 1년 간 여가시간 자유도 - 평일',
#  'Q11_4_1_N': '평균 여가 희망시간 - 평일',
#  'Q11_1_2_N': '지난 1년 간 하루 평균 여가시간 - 휴일',
#  'Q11_2_2': '지난 1년 간 여가시간 충분도 - 휴일',
#  'Q11_3_2': '지난 1년 간 여가시간 자유도 - 휴일',
#  'Q11_4_2_N': '평균 여가 희망시간 - 휴일',
#  'Q12_1_N': '여가시간 중 스마트기기 이용 시간 - 평일',
#  'Q12_2_N': '여가시간 중 스마트기기 이용 시간 - 휴일',
#  'Q13': '스마트기기 이용 시 가장 많이하는 여가활동',
#  'Q13_T': '스마트기기 이용 시 가장 많이하는 여가활동 - 기타(상세내용)',
#  'Q14': '지난 1년 간 휴가 사용 여부',
#  'Q14_1_N': '지난 1년 간 실제 사용 휴가 일수 - 전체',
#  'Q14_2_1_N': '지난 1년 간 실제 사용 휴가 일수 - 가을',
#  'Q14_2_2_N': '지난 1년 간 실제 사용 휴가 일수 - 겨울',
#  'Q14_2_3_N': '지난 1년 간 실제 사용 휴가 일수 - 봄',
#  'Q14_2_4_N': '지난 1년 간 실제 사용 휴가 일수 - 여름',
#  'Q14_3_1': '휴가기간 중 주 여가활동(1순위)',
#  'Q14_3_2': '휴가기간 중 주 여가활동(2순위)',
#  'Q14_3_3': '휴가기간 중 주 여가활동(3순위)',
#  'Q15_1': '집 외 가장 많이 이용한 여가공간 (1순위)',
#  'Q15_2': '집 외 가장 많이 이용한 여가공간 (2순위)',
#  'Q15_3': '집 외 가장 많이 이용한 여가공간 (3순위)',
#  'Q16_1': '집 외 가장 많이 이용하고 싶은 여가공간 (1순위)',
#  'Q16_2': '집 외 가장 많이 이용하고 싶은 여가공간 (2순위)',
#  'Q16_3': '집 외 가장 많이 이용하고 싶은 여가공간 (3순위)',
#  'Q17_1': '생활권 내 공공문화 및 여가시설 존재 인식',
#  'Q17_2': '생활권 내 공공문화 및 여가시설 이용 충분도',
#  'Q17_3': '생활권 내 공공문화 및 여가시설 프로그램 인지도',
#  'Q17_4': '생활권 내 공공문화 및 여가시설 프로그램 충분도',
#  'Q18': '생활권 내 공공문화여가시설 이용여부',
#  'Q19': '생활권 내 공공 문화여가시설 만족도',
#  'Q20_1': '민간 여가산업 만족도- 여가 관련 공간산업',
#  'Q20_2': '민간 여가산업 만족도- 여가 관련 용품산업',
#  'Q20_3': '민간 여가산업 만족도- 여가 관련 서비스산업',
#  'Q21': '지난 1년간 여가활동을 위한 동호회 참여 여부',
#  'Q21_1': '참여 동호회 주된 활동',
#  'Q21_2': '참여 동호회 부수적 활동',
#  'Q21_1_T': '참여 동호회 주된 활동(상세내용)',
#  'Q21_2_T': '참여 동호회 부수적 활동(상세내용)',
#  'Q22': '지난 1년간 자원봉사 참여 경험',
#  'Q22_1_1': '활동한 자원봉사 분야 (복수응답1) - 문화자원봉사 관련',
#  'Q22_1_2': '활동한 자원봉사 분야 (복수응답2) - 환경보전, 범죄예방 등과 관련',
#  'Q22_1_3': '활동한 자원봉사 분야 (복수응답3) - 국가 및 지역 행사 등과 관련',
#  'Q22_1_4': '활동한 자원봉사 분야 (복수응답4) - 아동, 청소년, 노인, 장애인, 재소자 등과 관련(복지시설,병원, 개인가정 봉사, 야학교사 등)',
#  'Q22_1_5': '활동한 자원봉사 분야 (복수응답5) - 재해지역 주민 돕기 및 시설복구 등과 관련',
#  'Q22_1_6': '활동한 자원봉사 분야 (복수응답6) - 일반인을 위한 봉사 관련(무료상담, 아이돌보기 등)',
#  'Q22_1_7': '활동한 자원봉사 분야 (복수응답7) - 기타',
#  'Q22_1_T': '활동한 자원봉사 분야 - 기타(상세내용)',
#  'Q23_1': '여가 정책 중요도 - 여가시설의 다양성',
#  'Q23_2': '여가 정책 중요도 - 질 좋은 여가프로그램 개발 및 보급',
#  'Q23_3': '여가 정책 중요도 - 여가관련 전문인력 양성 및 배치',
#  'Q23_4': '여가 정책 중요도 - 여가관련 동호회 육성 및 지원',
#  'Q23_5': '여가 정책 중요도 - 소외계층 여가생활 지원',
#  'Q23_6': '여가 정책 중요도 - 여가관련 법규와 제도 개선',
#  'Q23_7': '여가 정책 중요도 - 공휴일과 휴가를 법적 보장',
#  'Q23_1_1': '여가 정책 중요도 순위 (1순위)',
#  'Q23_1_2': '여가 정책 중요도 순위 (2순위)',
#  'Q23_1_3': '여가 정책 중요도 순위 (3순위)',
#  'Q24_1': '여가 정책 만족도 - 여가시설의 다양성',
#  'Q24_2': '여가 정책 만족도 - 질 좋은 여가프로그램 개발 및 보급',
#  'Q24_3': '여가 정책 만족도 - 여가관련 전문인력 양성 및 배치',
#  'Q24_4': '여가 정책 만족도 - 여가관련 동호회 육성 및 지원',
#  'Q24_5': '여가 정책 만족도 - 소외계층 여가생활 지원',
#  'Q24_6': '여가 정책 만족도 - 여가관련 법규와 제도 개선',
#  'Q24_7': '여가 정책 만족도 - 공휴일과 휴가를 법적 보장',
#  'Q25': '일(학업)과 여가의 균형',
#  'Q26': '더 많은 시간이 주어질 시 활용 계획',
#  'Q26_T': '더 많은 시간이 주어질 시 활용 계획 - 기타',
#  'Q27': '전반적 여가생활 만족도',
#  'Q28': '여가인식 - 여가활동이 삶의 필수적인 요건이다',
#  'Q29': '여가인식 - 여가활동이 삶의 긍정적 영향을 끼치는 지 여부',
#  'Q30': '현재 행복 수준 - 10점 척도',
#  'Q31_1': '여가활동 제약요인 - 시간부족',
#  'Q31_2': '여가활동 제약요인 - 경제적 지출 부담',
#  'Q31_3': '여가활동 제약요인 - 여가활동 경험 부족',
#  'Q31_4': '여가활동 제약요인 - 여가 정보 부족',
#  'Q31_5': '여가활동 제약요인 - 가족의 질병, 장애 등',
#  'Q31_6': '여가활동 제약요인 - 여가 동반자 없음',
#  'Q31_7': '여가활동 제약요인 - 여가시설 및 프로그램 부족',
#  'Q31_8': '여가활동 제약요인 - 기후 여건(미세먼지, 폭염 등)',
#  'Q31_9': '여가활동 제약요인 - 감염병',
#  'Q32_1': '본인의 교육정도 - 최종학력',
#  'Q32_2': '본인의 교육정도 - 이수여부',
#  'Q33': '혼인상태',
#  'Q33_T': '혼인상태 - 기타',
#  'Q34_N': '만 나이',
#  'Q35_1': '응답자 장애등록 여부',
#  'Q35_1_1': '응답자 장애정도',
#  'Q35_2': '응답자 본인 외 가족 장애등록 여부',
#  'Q35_2_1': '응답자 본인 외 가족 장애정도',
#  'Q36_1_N': '전체 동거 가구원 수',
#  'Q36_2_N': '만 15세 이상 동거 가구원 수',
#  'Q36_1_1': '동거 자녀 현황 (복수응답1) - 자녀 없음',
#  'Q36_1_2': '동거 자녀 현황 (복수응답2) - 미취학아동 자녀(0세~만 5세 이하)',
#  'Q36_1_3': '동거 자녀 현황 (복수응답3) - 취학 자녀(만 6세 ~ 만 18세 이하)',
#  'Q36_1_4': '동거 자녀 현황 (복수응답4) - 성인 자녀(만 19세 이상)',
#  'Q36_1_2_N': '미취학아동 자녀 수',
#  'Q36_1_3_N': '취학 자녀 수',
#  'Q36_1_4_N': '성인 자녀 수',
#  'Q37': '가구주 여부',
#  'Q37_1': '가구주와의 관계',
#  'Q37_2': '응답자 성별',
#  'Q37_3': '가구주의 성별',
#  'Q37_4': '가구주의 학력 - 최종학력',
#  'Q37_5': '가구주의 학력 - 이수여부',
#  'Q38': '본인의 신체적 건강상태 인식',
#  'Q39': '본인의 정신적 건강상태 인식',
#  'Q40': '본인의 사회적 건강상태 인식',
#  'Q41': '지난 1주일 간 경제활동 여부',
#  'Q41_1': '경제활동 한 경우 직업 - 주업',
#  'Q41_2': '경제활동 한 경우 직업 - 부업',
#  'Q41_3': '경제활동 없는 경우 - 직업',
#  'Q41_4': '종사상의 지위',
#  'Q41_5_N': '주당 평균 근무 시간',
#  'Q41_6': '직장내 근무형태',
#  'Q41_7': '유연근무제 시행 여부',
#  'Q42_1': '지난 1년 간 세금 공제 전 월 평균 소득- 본인',
#  'Q42_2': '지난 1년 간 세금 공제 전 월 평균 소득- 가구',
#  'WT': '가중치',
#  'DM1': '성별',
#  'DM2': '연령',
#  'DM3': '학력',
#  'DM4': '동거 가구원수',
#  'DM5': '혼인상태',
#  'DM6': '가구주 여부',
#  'DM7': '종사상 지위',
#  'DM8': '가구 소득',
#  'DM9': '지역규모',
#  'DM10': '권역',
#  'DM11': '지역(시도)',
#  'DM12': '장애여부',
#  'DM13': '근무형태',
#  'DM14': '유연근무제 여부'}

# %%
fir_col_dic = []
Q_col_dic = []
last_col_dic = []

for column in code_dict.keys()[:4]:
    print(column)
for column in code_dict.keys()[]:
    print(column)
# Out:
# ID
# EUP
# AREA
# APT
# Q1_1
# Q1_2
# Q1_3
# Q1_4
# Q1_5
# Q1_6
# Q1_7
# Q1_8
# Q1_9
# Q1_10
# Q1_11
# Q1_12
# Q1_13
# Q1_14
# Q1_15
# Q1_16
# Q1_17
# Q1_18
# Q1_19
# Q1_20
# Q1_21
# Q1_22
# Q1_23
# Q1_24
# Q1_25
# Q1_26
# Q1_27
# Q1_28
# Q1_29
# Q1_30
# Q1_31
# Q1_32
# Q1_33
# Q1_34
# Q1_35
# Q1_36
# Q1_37
# Q1_38
# Q1_39
# Q1_40
# Q1_41
# Q1_42
# Q1_43
# Q1_44
# Q1_45
# Q1_46
# Q1_47
# Q1_48
# Q1_49
# Q1_50
# Q1_51
# Q1_52
# Q1_53
# Q1_54
# Q1_55
# Q1_56
# Q1_57
# Q1_58
# Q1_59
# Q1_60
# Q1_61
# Q1_62
# Q1_63
# Q1_64
# Q1_65
# Q1_66
# Q1_67
# Q1_68
# Q1_69
# Q1_70
# Q1_71
# Q1_72
# Q1_73
# Q1_74
# Q1_75
# Q1_76
# Q1_77
# Q1_78
# Q1_79
# Q1_80
# Q1_81
# Q1_82
# Q1_83
# Q1_84
# Q1_85
# Q1_86
# Q1_87
# Q1_88
# Q1_89
# Q1_90
# Q1_91
# Q2_1_1
# Q2_1_2
# Q2_1_3
# Q2_1_4
# Q2_1_5
# Q2_2_1
# Q2_2_2
# Q2_2_3
# Q2_2_4
# Q2_2_5
# Q2_2_1_T
# Q2_2_2_T
# Q2_2_3_T
# Q2_2_4_T
# Q2_2_5_T
# Q2_3_1
# Q2_3_2
# Q2_3_3
# Q2_3_4
# Q2_3_5
# Q2_3_1_T
# Q2_3_2_T
# Q2_3_3_T
# Q2_3_4_T
# Q2_3_5_T
# Q2_4_1_1_N
# Q2_4_1_2_N
# Q2_4_2_1_N
# Q2_4_2_2_N
# Q2_4_3_1_N
# Q2_4_3_2_N
# Q2_4_4_1_N
# Q2_4_4_2_N
# Q2_4_5_1_N
# Q2_4_5_2_N
# Q2_5_1_N
# Q2_5_2_N
# Q2_5_3_N
# Q2_5_4_N
# Q2_5_5_N
# Q2_6_1
# Q2_6_2
# Q2_6_3
# Q2_6_4
# Q2_6_5
# Q3
# Q3_T
# Q4_1
# Q4_2
# Q4_3
# Q5_1_A
# Q5_2_A
# Q5_3_A
# Q5_4_A
# Q5_1_B
# Q5_2_B
# Q5_3_B
# Q5_4_B
# Q5_1_C
# Q5_2_C
# Q5_3_C
# Q5_4_C
# Q5_1_D
# Q5_2_D
# Q5_3_D
# Q5_4_D
# Q5_1_E
# Q5_2_E
# Q5_3_E
# Q5_4_E
# Q5_1_F
# Q5_2_F
# Q5_3_F
# Q5_4_F
# Q5_1_G
# Q5_2_G
# Q5_3_G
# Q5_4_G
# Q5_1_H
# Q5_2_H
# Q5_3_H
# Q5_4_H
# Q6
# Q7
# Q7_T
# Q8_1_N
# Q8_2_N
# Q9_N
# Q9_1
# Q10_N
# Q11_1_1_N
# Q11_2_1
# Q11_3_1
# Q11_4_1_N
# Q11_1_2_N
# Q11_2_2
# Q11_3_2
# Q11_4_2_N
# Q12_1_N
# Q12_2_N
# Q13
# Q13_T
# Q14
# Q14_1_N
# Q14_2_1_N
# Q14_2_2_N
# Q14_2_3_N
# Q14_2_4_N
# Q14_3_1
# Q14_3_2
# Q14_3_3
# Q15_1
# Q15_2
# Q15_3
# Q16_1
# Q16_2
# Q16_3
# Q17_1
# Q17_2
# Q17_3
# Q17_4
# Q18
# Q19
# Q20_1
# Q20_2
# Q20_3
# Q21
# Q21_1
# Q21_2
# Q21_1_T
# Q21_2_T
# Q22
# Q22_1_1
# Q22_1_2
# Q22_1_3
# Q22_1_4
# Q22_1_5
# Q22_1_6
# Q22_1_7
# Q22_1_T
# Q23_1
# Q23_2
# Q23_3
# Q23_4
# Q23_5
# Q23_6
# Q23_7
# Q23_1_1
# Q23_1_2
# Q23_1_3
# Q24_1
# Q24_2
# Q24_3
# Q24_4
# Q24_5
# Q24_6
# Q24_7
# Q25
# Q26
# Q26_T
# Q27
# Q28
# Q29
# Q30
# Q31_1
# Q31_2
# Q31_3
# Q31_4
# Q31_5
# Q31_6
# Q31_7
# Q31_8
# Q31_9
# Q32_1
# Q32_2
# Q33
# Q33_T
# Q34_N
# Q35_1
# Q35_1_1
# Q35_2
# Q35_2_1
# Q36_1_N
# Q36_2_N
# Q36_1_1
# Q36_1_2
# Q36_1_3
# Q36_1_4
# Q36_1_2_N
# Q36_1_3_N
# Q36_1_4_N
# Q37
# Q37_1
# Q37_2
# Q37_3
# Q37_4
# Q37_5
# Q38
# Q39
# Q40
# Q41
# Q41_1
# Q41_2
# Q41_3
# Q41_4
# Q41_5_N
# Q41_6
# Q41_7
# Q42_1
# Q42_2
# WT
# DM1
# DM2
# DM3
# DM4
# DM5
# DM6
# DM7
# DM8
# DM9
# DM10
# DM11
# DM12
# DM13
# DM14

# %%
# 파일 읽어오기 - 에러발생시 현재 파일과 상대파일 경로 꼭! 재확인!
db1_df = pd.read_csv("../../data/순위별 비용.csv")

# # 우리가 가진 데이터에서 base값은 91번컬럼까지있으니 확인!
# base_df = db1_df.iloc[:,:92]
# culture_df = db1_df.iloc[:,92:]

# display(base_df.head())
# display(culture_df.head())

# %%
db1_df
# Out:
#             ID  Q2_5_1_N  Q2_5_2_N  Q2_5_3_N  Q2_5_4_N  Q2_5_5_N   Q10_N
# 0      1003001         0       0.0       0.0   30000.0     500.0  300000
# 1      1003002      2000       0.0    5000.0       0.0   50000.0  450000
# 2      1003003         0       0.0   30000.0       0.0   80000.0  300000
# 3      1003004         0       0.0   50000.0   50000.0    5000.0  300000
# 4      1003021      2000   30000.0   50000.0       0.0       0.0  200000
# ...        ...       ...       ...       ...       ...       ...     ...
# 10035  2505067     30000   30000.0    2000.0   30000.0   50000.0  200000
# 10036  2505068     20000   30000.0   20000.0   20000.0   30000.0  300000
# 10037  2505069     20000   30000.0   50000.0   20000.0    1000.0  200000
# 10038  2505070     30000    1000.0   30000.0   30000.0   10000.0  200000
# 10039  2505071     20000   20000.0    5000.0   20000.0   30000.0  200000
#
# [10040 rows x 7 columns]
